# %%
pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)

# %%
import pandas as pd
import numpy as np
import warnings
from langdetect import detect
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
comments = pd.read_csv("/content/drive/MyDrive/Data Sci Proj/Comments.csv")

# %%
# Read the first 10,000 values of the dataset
comments_subset = pd.read_csv("/content/drive/MyDrive/Data Sci Proj/Comments.csv", nrows=10000)

# %%
comments.head()
# Out:
#           id  course_id  rate                       date   display_name  \
# 0   88962892    3173036   1.0  2021-06-29T18:54:25-07:00          Rahul
# 1  125535470    4913148   5.0  2022-10-07T11:17:41-07:00          Marlo
# 2   68767147    3178386   3.5  2020-10-19T06:35:37-07:00  Yamila Andrea
# 3  125029758    3175814   5.0  2022-09-30T21:13:49-07:00     Jacqueline
# 4   76584052    3174896   4.5  2021-01-30T08:45:11-08:00        Anthony
#
#                                              comment
# 0  I think a beginner needs more than you think.\...
# 1  Aviva is such a natural teacher and healer/hea...
# 2  Muy buena la introducción para entender la bas...
# 3  This course is the best on Udemy.  This breakd...
# 4  I found this course very helpful. It was full ...

# %%
def detect_language(text):
    try:
        lang = detect(text)
    except:
        lang = 'unknown'
    return lang

# %%
# comments['language'] = comments['comment'].apply(detect_language)
# comments = comments[comments['language'] == 'en']
# comments = comments.drop(columns=['language'])

comments_subset['language'] = comments_subset['comment'].apply(detect_language)
comments_subset = comments_subset[comments_subset['language'] == 'en']
comments_subset = comments_subset.drop(columns=['language'])

# %%
# Out:
# id              0
# course_id       0
# rate            0
# date            0
# display_name    0
# comment         0
# dtype: int64

# %%
comment_1 = comments_subset[comments_subset["rate"] <= 1]  # Select comments with rate values in the interval [0, 1]
comment_2 = comments_subset[(comments_subset["rate"] > 1) & (comments_subset["rate"] <= 2)]  # Select comments with rate values in the interval (1, 2]
comment_3 = comments_subset[(comments_subset["rate"] > 2) & (comments_subset["rate"] <= 3)]  # Select comments with rate values in the interval (2, 3]
comment_4 = comments_subset[(comments_subset["rate"] > 3) & (comments_subset["rate"] <= 4)]  # Select comments with rate values in the interval (3, 4]
comment_5 = comments_subset[comments_subset["rate"] > 4]  # Select comments with rate values in the interval (4, 5]

# %%
rate_1 = len(comment_1) / len(comments_subset)*100
rate_2 = len(comment_2) / len(comments_subset)*100
rate_3 = len(comment_3) / len(comments_subset)*100
rate_4 = len(comment_4) / len(comments_subset)*100
rate_5 = len(comment_5) / len(comments_subset)*100

# %%
print(f"Percentage of comments rated below 1.0 is {rate_1}")
print(f"Percentage of comments rated above 1.0 and below 2.0 is {rate_2}")
print(f"Percentage of comments rated above 2.0 and below 3.0 is {rate_3}")
print(f"Percentage of comments rated above 3.0 and below 4.0 is {rate_4}")
print(f"Percentage of comments rated above 4.0 is {rate_5}")
# Out:
# Percentage of comments rated below 1.0 is 8.551798951365033
# Percentage of comments rated above 1.0 and below 2.0 is 4.429578738022057
# Percentage of comments rated above 2.0 and below 3.0 is 7.340444765865124
# Percentage of comments rated above 3.0 and below 4.0 is 10.377870186223106
# Percentage of comments rated above 4.0 is 69.30030735852468

# %%
comments_subset.head()
# Out:
#           id  course_id  rate                       date display_name  \
# 0   88962892    3173036   1.0  2021-06-29T18:54:25-07:00        Rahul
# 1  125535470    4913148   5.0  2022-10-07T11:17:41-07:00        Marlo
# 3  125029758    3175814   5.0  2022-09-30T21:13:49-07:00   Jacqueline
# 4   76584052    3174896   4.5  2021-01-30T08:45:11-08:00      Anthony
# 5  124129784    4693438   1.0  2022-09-20T11:30:29-07:00        Jiang
#
#                                              comment
# 0  I think a beginner needs more than you think.\...
# 1  Aviva is such a natural teacher and healer/hea...
# 3  This course is the best on Udemy.  This breakd...
# 4  I found this course very helpful. It was full ...
# 5                         nothing information there,

# %%
all_comments = comments_subset[["course_id", "rate", "display_name", "comment"]]

# %%
all_comments.head()
# Out:
#    course_id  rate display_name  \
# 0    3173036   1.0        Rahul
# 1    4913148   5.0        Marlo
# 3    3175814   5.0   Jacqueline
# 4    3174896   4.5      Anthony
# 5    4693438   1.0        Jiang
#
#                                              comment
# 0  I think a beginner needs more than you think.\...
# 1  Aviva is such a natural teacher and healer/hea...
# 3  This course is the best on Udemy.  This breakd...
# 4  I found this course very helpful. It was full ...
# 5                         nothing information there,

# %%
comments_shuffled = all_comments.sample(frac=1, random_state=1).reset_index().drop(["index"], axis=1)

# %%
comments_shuffled.head(10)
# Out:
#    course_id  rate display_name  \
# 0    4181398   4.5         Syed
# 1    2951938   2.0      Bethany
# 2    4520682   5.0      Santosh
# 3    4905460   5.0        James
# 4    4886302   5.0       Alonzo
# 5    4693438   1.0        Jiang
# 6    2161340   5.0      MaryAnn
# 7    4046828   5.0       Aurora
# 8    4840590   5.0           AR
# 9    4689906   1.5       Shallu
#
#                                              comment
# 0       Very informative and intuitive explanations.
# 1  Unprofessional but had some valuable tidbits o...
# 2  Explain in simple words with covering all the ...
# 3  What a great course. I’m heading to Barcelona ...
# 4                       Great Simulator for the Exam
# 5                         nothing information there,
# 6  What Leon is teaching and exploring helps us t...
# 7                          Great. I like the course.
# 8                    This course was really amazing.
# 9  actually she is not explaining the material wh...

# %%
comments_shuffled["comment"] = comments_shuffled["comment"].apply(lambda txt: txt.lower())

# %%
import re
def leave_only_words(comment):
    for idx in range(len(comment)):
        comments_shuffled["comment"][idx] = re.sub(r'[^a-zA-Z ]+', '', comments_shuffled["comment"][idx])

# %%
# %%time
leave_only_words(comments_shuffled["comment"])
# Out:
# CPU times: user 1.83 s, sys: 74.5 ms, total: 1.9 s
# Wall time: 1.97 s

# %%
! pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.2.2)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %% [markdown]
# **SentimentIntensityAnalyzer will analyse the comments and return a dict which contains scores such as:**
#
# Negative(neg): Negativity value of the comment
#
# Neutral(neu): Neutrality value of the comment
#
# Positive(pos): Positivity value of the comment
#
# Compound(compound): Compound value of the comment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
comments_shuffled["scores"] = comments_shuffled["comment"].apply(lambda txt: analyzer.polarity_scores(txt))

# %%
comments_shuffled.head(10)
# Out:
#    course_id  rate display_name  \
# 0    4181398   4.5         Syed
# 1    2951938   2.0      Bethany
# 2    4520682   5.0      Santosh
# 3    4905460   5.0        James
# 4    4886302   5.0       Alonzo
# 5    4693438   1.0        Jiang
# 6    2161340   5.0      MaryAnn
# 7    4046828   5.0       Aurora
# 8    4840590   5.0           AR
# 9    4689906   1.5       Shallu
#
#                                              comment  \
# 0        very informative and intuitive explanations
# 1  unprofessional but had some valuable tidbits o...
# 2  explain in simple words with covering all the ...
# 3  what a great course im heading to barcelona at...
# 4                       great simulator for the exam
# 5                          nothing information there
# 6  what leon is teaching and exploring helps us t...
# 7                            great i like the course
# 8                     this course was really amazing
# 9  actually she is not explaining the material wh...
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.085, 'neu': 0.63, 'pos': 0.285, 'com...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'comp...
# 4  {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'comp...
# 5  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6  {'neg': 0.0, 'neu': 0.836, 'pos': 0.164, 'comp...
# 7  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...
# 8  {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'comp...
# 9  {'neg': 0.082, 'neu': 0.918, 'pos': 0.0, 'comp...

# %%
comments_shuffled["negative"] = comments_shuffled["scores"].apply(lambda txt: txt["neg"])
comments_shuffled["neutral"] = comments_shuffled["scores"].apply(lambda txt: txt["neu"])
comments_shuffled["positive"] = comments_shuffled["scores"].apply(lambda txt: txt["pos"])
comments_shuffled["compound"] = comments_shuffled["scores"].apply(lambda txt: txt["compound"])

# %%
comment_scores = comments_shuffled.drop(["comment", "scores"], axis=1)[["negative", "neutral", "positive", "compound", "rate"]]

# %%
comment_scores.head(10)
# Out:
#    negative  neutral  positive  compound  rate
# 0     0.000    1.000     0.000    0.0000   4.5
# 1     0.085    0.630     0.285    0.7269   2.0
# 2     0.000    1.000     0.000    0.0000   5.0
# 3     0.000    0.735     0.265    0.8957   5.0
# 4     0.000    0.494     0.506    0.6249   5.0
# 5     0.000    1.000     0.000    0.0000   1.0
# 6     0.000    0.836     0.164    0.6249   5.0
# 7     0.000    0.312     0.688    0.7650   5.0
# 8     0.000    0.494     0.506    0.6240   5.0
# 9     0.082    0.918     0.000   -0.3401   1.5
